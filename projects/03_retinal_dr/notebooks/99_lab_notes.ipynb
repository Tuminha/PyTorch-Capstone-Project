# %% [markdown]
# # Lab Notes - Retinal DR## Template for ReflectionUse this notebook to log your progress, insights, and challenges throughout the project.### Entry Template- **Date:** YYYY-MM-DD- **Goal:** What were you trying to accomplish?- **What clicked:** What made sense today?- **What confused me:** What was unclear?- **One change for next time:** What would you do differently?- **Next experiment:** What will you try next?

# %% [markdown]
# ## Entry 1

# %% [markdown]
# **Date:** **Goal:** **What clicked:** **What confused me:** **One change for next time:** **Next experiment:**
